# %%
#tells the title of the game

print("Tic Tac Toe Game!\n")

 
#creates empty table for game
table=[]
for i in range(0,9):
    table.append("_")

#this is the list containing all choices made by both teams    
l=[]
# Out:
# Tic Tac Toe Game!

# %%
#follwoing are all function definitions are typed in this section:

#Function-shows the game board to the player
def show_board(table):
    print(table[0]+" "+table[1]+" "+table[2]+"\n"+table[3]+" "+table[4]+" "+table[5]+"\n"+table[6]+" "+table[7]+" "+table[8])


#changes and shows the new game table
def change_table(move):
    table[int(move)-1]=str(team)

#creates choice of position for opponent
def choice():
    import random
    result=random.randrange(1,10)
    if str(result) in l:
        result=choice()
    else:
        l.append(str(result))
    return result
#asks the user for their choice

def enter_choice():
    move=input("\nENTER POSITION\n")
    if move in l:
        print("Invalid entry.Choose another position\n")
        move=enter_choice()
    else:
        l.append(move)
    return move

#changes the team
def team_change(team):
    if team=='X':
        team='O'
    else:
       team ='X'
    return team

# %%
#start of game 
print("Gameboard:\n\n")
show_board(table)
print("\nYOU ARE TEAM X.Team X starts the game ")
team='X'

draw=1



print("Team X turn")
move=enter_choice()
change_table(move)
show_board(table)


for i in range(0,9):
    print("positions taken are\n")
    print(l)
    if team=='X':
        team='O'
    else:
       team ='X'
   
    if team=='X':
        print("Team X turn")
        move=enter_choice()
    else:
        print("Team O turn")
        move=choice()
        
    
    change_table(move)
    show_board(table)
    
    
    #different cases in which game can end
    case_a=table[0] == table[1] == table[2]==team
    case_A=table[0] == table[1] == table[2]==team
    case_b=table[3] == table[4]==table[5]==team 
    case_B=table[3] == table[4] == table[5]==team
    case_c=table[6] == table[7] == table[8]==team
    case_C=table[6] == table[7] == table[8]==team
    case_d=table[0] == table[3] == table[6]==team
    case_D=table[0] == table[3] == table[6]==team
    case_e=table[1] ==table[4]== table[7]==team
    case_E=table[1] ==table[4] == table[7]==team
    case_f=table[2] == table[5] == table[8]==team
    case_F=table[2] == table[5] == table[8]==team
    case_g=table[0] == table[4] == table[8]==team
    case_G=table[0] == table[4] == table[8]==team
    case_h=table[2] == table[4] == table[6]==team
    case_H=table[2] == table[4] == table[6]==team


   
    if (case_a or case_b or case_c or case_d or case_e or case_f or case_g or case_h or case_A or case_B or case_C or case_D or case_E or case_F or case_G or case_H)==True:
        
        
        draw=0
        break
        
    
        
        
    
        
if(draw==1):       
    print("Draw\nGAME OVER")
else:
    print("Winner is Team "+team+ "\nGAME OVER ")
# Out:
# Gameboard:
#
#
# _ _ _
# _ _ _
# _ _ _
#
# YOU ARE TEAM X.Team X starts the game
# Team X turn
